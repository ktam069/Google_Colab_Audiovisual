# %% [markdown]
# <a href="https://colab.research.google.com/github/ktam069/Google_Colab_Audiovisual/blob/master/Modified_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !rm -r "data/"
# !unzip "/content/gdrive/My Drive/Part IV Project/Colab Modified/data.zip"
# Out:
# Archive:  /content/gdrive/My Drive/Part IV Project/Colab Modified/data.zip
#    creating: data/audio/
#    creating: data/audio/__pycache__/
#   inflating: data/audio/__pycache__/audio_downloader.cpython-36.pyc
#   inflating: data/audio/__pycache__/audio_norm.cpython-36.pyc
#   inflating: data/audio/__pycache__/build_audio_database_v2.cpython-36.pyc
#   inflating: data/audio/audio_downloader.py
#   inflating: data/audio/audio_norm.py
#    creating: data/audio/audio_train/
#   inflating: data/audio/audio_train/trim_audio_train0.wav
#   inflating: data/audio/audio_train/trim_audio_train1.wav
#   inflating: data/audio/audio_train/trim_audio_train10.wav
#   inflating: data/audio/audio_train/trim_audio_train100.wav
#   inflating: data/audio/audio_train/trim_audio_train11.wav
#   inflating: data/audio/audio_train/trim_audio_train12.wav
#   inflating: data/audio/audio_train/trim_audio_train13.wav
#   inflating: data/audio/audio_train/trim_audio_train14.wav
#   inflating: data/audio/audio_train/trim_audio_train15.wav
#   inflating: data/audio/audio_train/trim_audio_train16.wav
#   inflating: data/audio/audio_train/trim_audio_train17.wav
#   inflating: data/audio/audio_train/trim_audio_train18.wav
#   inflating: data/audio/audio_train/trim_audio_train19.wav
#   inflating: data/audio/audio_train/trim_audio_train2.wav
#   inflating: data/audio/audio_train/trim_audio_train20.wav
#   inflating: data/audio/audio_train/trim_audio_train21.wav
#   inflating: data/audio/audio_train/trim_audio_train22.wav
#   inflating: data/audio/audio_train/trim_audio_train23.wav
#   inflating: data/audio/audio_train/trim_audio_train24.wav
#   inflating: data/audio/audio_train/trim_audio_train26.wav
#   inflating: data/audio/audio_train/trim_audio_train27.wav
#   inflating: data/audio/audio_train/trim_audio_train28.wav
#   inflating: data/audio/audio_train/trim_audio_train29.wav
#   inflating: data/audio/audio_train/trim_audio_train3.wav
#   inflating: data/audio/audio_train/trim_audio_train30.wav
#   inflating: data/audio/audio_train/trim_audio_train32.wav
#   inflating: data/audio/audio_train/trim_audio_train33.wav
#   inflating: data/audio/audio_train/trim_audio_train34.wav
#   inflating: data/audio/audio_train/trim_audio_train35.wav
#   inflating: data/audio/audio_train/trim_audio_train36.wav
#   inflating: data/audio/audio_train/trim_audio_train37.wav
#   inflating: data/audio/audio_train/trim_audio_train38.wav
#   inflating: data/audio/audio_train/trim_audio_train39.wav
#   inflating: data/audio/audio_train/trim_audio_train4.wav
#   inflating: data/audio/audio_train/trim_audio_train40.wav
#   inflating: data/audio/audio_train/trim_audio_train41.wav
#   inflating: data/audio/audio_train/trim_audio_train42.wav
#   inflating: data/audio/audio_train/trim_audio_train43.wav
#   inflating: data/audio/audio_train/trim_audio_train44.wav
#   inflating: data/audio/audio_train/trim_audio_train45.wav
#   inflating: data/audio/audio_train/trim_audio_train46.wav
#   inflating: data/audio/audio_train/trim_audio_train47.wav
#   inflating: data/audio/audio_train/trim_audio_train48.wav
#   inflating: data/audio/audio_train/trim_audio_train5.wav
#   inflating: data/audio/audio_train/trim_audio_train50.wav
#   inflating: data/audio/audio_train/trim_audio_train52.wav
#   inflating: data/audio/audio_train/trim_audio_train53.wav
#   inflating: data/audio/audio_train/trim_audio_train54.wav
#   inflating: data/audio/audio_train/trim_audio_train55.wav
#   inflating: data/audio/audio_train/trim_audio_train56.wav
#   inflating: data/audio/audio_train/trim_audio_train57.wav
#   inflating: data/audio/audio_train/trim_audio_train58.wav
#   inflating: data/audio/audio_train/trim_audio_train59.wav
#   inflating: data/audio/audio_train/trim_audio_train6.wav
#   inflating: data/audio/audio_train/trim_audio_train61.wav
#   inflating: data/audio/audio_train/trim_audio_train62.wav
#   inflating: data/audio/audio_train/trim_audio_train63.wav
#   inflating: data/audio/audio_train/trim_audio_train64.wav
#   inflating: data/audio/audio_train/trim_audio_train65.wav
#   inflating: data/audio/audio_train/trim_audio_train66.wav
#   inflating: data/audio/audio_train/trim_audio_train67.wav
#   inflating: data/audio/audio_train/trim_audio_train68.wav
#   inflating: data/audio/audio_train/trim_audio_train69.wav
#   inflating: data/audio/audio_train/trim_audio_train7.wav
#   inflating: data/audio/audio_train/trim_audio_train70.wav
#   inflating: data/audio/audio_train/trim_audio_train71.wav
#   inflating: data/audio/audio_train/trim_audio_train72.wav
#   inflating: data/audio/audio_train/trim_audio_train73.wav
#   inflating: data/audio/audio_train/trim_audio_train74.wav
#   inflating: data/audio/audio_train/trim_audio_train75.wav
#   inflating: data/audio/audio_train/trim_audio_train76.wav
#   inflating: data/audio/audio_train/trim_audio_train78.wav
#   inflating: data/audio/audio_train/trim_audio_train79.wav
#   inflating: data/audio/audio_train/trim_audio_train8.wav
#   inflating: data/audio/audio_train/trim_audio_train81.wav
#   inflating: data/audio/audio_train/trim_audio_train82.wav
#   inflating: data/audio/audio_train/trim_audio_train83.wav
#   inflating: data/audio/audio_train/trim_audio_train84.wav
#   inflating: data/audio/audio_train/trim_audio_train86.wav
#   inflating: data/audio/audio_train/trim_audio_train87.wav
#   inflating: data/audio/audio_train/trim_audio_train88.wav
#   inflating: data/audio/audio_train/trim_audio_train89.wav
#   inflating: data/audio/audio_train/trim_audio_train9.wav
#   inflating: data/audio/audio_train/trim_audio_train90.wav
#   inflating: data/audio/audio_train/trim_audio_train91.wav
#   inflating: data/audio/audio_train/trim_audio_train92.wav
#   inflating: data/audio/audio_train/trim_audio_train93.wav
#   inflating: data/audio/audio_train/trim_audio_train94.wav
#   inflating: data/audio/audio_train/trim_audio_train95.wav
#   inflating: data/audio/audio_train/trim_audio_train96.wav
#   inflating: data/audio/audio_train/trim_audio_train97.wav
#   inflating: data/audio/audio_train/trim_audio_train98.wav
#   inflating: data/audio/audio_train/trim_audio_train99.wav
#    creating: data/audio/AV_model_database/
#    creating: data/audio/AV_model_database/crm/
#   inflating: data/audio/AV_model_database/crm/crm-00021-00065-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00068-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00069-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00070-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00072-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00073-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00075-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00078-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00079-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00081-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00083-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00084-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00087-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00088-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00091-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00092-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00093-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00094-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00096-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00097-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00099-00021.npy
#   inflating: data/audio/AV_model_database/crm/crm-00021-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00065-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00068-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00069-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00070-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00072-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00073-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00075-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00078-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00079-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00081-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00083-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00084-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00087-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00088-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00091-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00092-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00093-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00094-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00096-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00097-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00099-00024.npy
#   inflating: data/audio/AV_model_database/crm/crm-00024-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00065-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00068-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00069-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00070-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00072-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00073-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00075-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00078-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00079-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00081-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00083-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00084-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00087-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00088-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00091-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00092-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00093-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00094-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00096-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00097-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00099-00030.npy
#   inflating: data/audio/AV_model_database/crm/crm-00030-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00065-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00068-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00069-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00070-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00072-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00073-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00075-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00078-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00079-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00081-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00083-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00084-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00087-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00088-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00091-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00092-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00093-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00094-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00096-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00097-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00099-00032.npy
#   inflating: data/audio/AV_model_database/crm/crm-00032-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00065-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00068-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00069-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00070-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00072-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00073-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00075-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00078-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00079-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00081-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00083-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00084-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00087-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00088-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00091-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00092-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00093-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00094-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00096-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00097-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00099-00034.npy
#   inflating: data/audio/AV_model_database/crm/crm-00034-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00065-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00068-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00069-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00070-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00072-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00073-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00075-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00078-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00079-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00081-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00083-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00084-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00087-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00088-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00091-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00092-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00093-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00094-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00096-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00097-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00099-00035.npy
#   inflating: data/audio/AV_model_database/crm/crm-00035-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00065-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00068-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00069-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00070-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00072-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00073-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00075-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00078-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00079-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00081-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00083-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00084-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00087-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00088-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00091-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00092-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00093-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00094-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00096-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00097-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00099-00038.npy
#   inflating: data/audio/AV_model_database/crm/crm-00038-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00065-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00068-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00069-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00070-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00072-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00073-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00075-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00078-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00079-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00081-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00083-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00084-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00087-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00088-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00091-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00092-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00093-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00094-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00096-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00097-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00099-00040.npy
#   inflating: data/audio/AV_model_database/crm/crm-00040-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00065-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00068-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00069-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00070-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00072-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00073-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00075-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00078-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00079-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00081-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00083-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00084-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00087-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00088-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00091-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00092-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00093-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00094-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00096-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00097-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00099-00041.npy
#   inflating: data/audio/AV_model_database/crm/crm-00041-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00065-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00068-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00069-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00070-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00072-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00073-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00075-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00078-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00079-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00081-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00083-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00084-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00087-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00088-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00091-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00092-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00093-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00094-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00096-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00097-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00099-00042.npy
#   inflating: data/audio/AV_model_database/crm/crm-00042-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00065-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00068-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00069-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00070-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00072-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00073-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00075-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00078-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00079-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00081-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00083-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00084-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00087-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00088-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00091-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00092-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00093-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00094-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00096-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00097-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00099-00043.npy
#   inflating: data/audio/AV_model_database/crm/crm-00043-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00065-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00068-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00069-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00070-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00072-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00073-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00075-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00078-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00079-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00081-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00083-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00084-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00087-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00088-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00091-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00092-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00093-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00094-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00096-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00097-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00099-00044.npy
#   inflating: data/audio/AV_model_database/crm/crm-00044-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00065-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00068-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00069-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00070-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00072-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00073-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00075-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00078-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00079-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00079-00079.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00081-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00081-00081.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00083-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00083-00083.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00084-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00084-00084.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00087-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00087-00087.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00088-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00088-00088.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00091-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00091-00091.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00092-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00092-00092.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00093-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00093-00093.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00094-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00094-00094.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00096-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00096-00096.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00097-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00097-00097.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00099-00045.npy
#   inflating: data/audio/AV_model_database/crm/crm-00045-00099-00099.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00065-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00065-00065.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00068-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00068-00068.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00069-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00069-00069.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00070-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00070-00070.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00072-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00072-00072.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00073-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00073-00073.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00075-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00075-00075.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00078-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00078-00078.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00079-00048.npy
#   inflating: data/audio/AV_model_database/crm/crm-00048-00079-00079.npy
# ...
#   inflating: data/video/frames/95-30.jpg
#   inflating: data/video/frames/95-31.jpg
#   inflating: data/video/frames/95-32.jpg
#   inflating: data/video/frames/95-33.jpg
#   inflating: data/video/frames/95-34.jpg
#   inflating: data/video/frames/95-35.jpg
#   inflating: data/video/frames/95-36.jpg
#   inflating: data/video/frames/95-37.jpg
#   inflating: data/video/frames/95-38.jpg
#   inflating: data/video/frames/95-39.jpg
#   inflating: data/video/frames/9-54.jpg
#   inflating: data/video/frames/95-40.jpg
#   inflating: data/video/frames/95-41.jpg
#   inflating: data/video/frames/95-42.jpg
#   inflating: data/video/frames/95-43.jpg
#   inflating: data/video/frames/95-44.jpg
#   inflating: data/video/frames/95-45.jpg
#   inflating: data/video/frames/95-46.jpg
#   inflating: data/video/frames/95-47.jpg
#   inflating: data/video/frames/95-48.jpg
#   inflating: data/video/frames/95-49.jpg
#   inflating: data/video/frames/9-55.jpg
#   inflating: data/video/frames/95-50.jpg
#   inflating: data/video/frames/95-51.jpg
#   inflating: data/video/frames/95-52.jpg
#   inflating: data/video/frames/95-53.jpg
#   inflating: data/video/frames/95-54.jpg
#   inflating: data/video/frames/95-55.jpg
#   inflating: data/video/frames/95-56.jpg
#   inflating: data/video/frames/95-57.jpg
#   inflating: data/video/frames/95-58.jpg
#   inflating: data/video/frames/95-59.jpg
#   inflating: data/video/frames/9-56.jpg
#   inflating: data/video/frames/95-60.jpg
#   inflating: data/video/frames/95-61.jpg
#   inflating: data/video/frames/95-62.jpg
#   inflating: data/video/frames/95-63.jpg
#   inflating: data/video/frames/95-64.jpg
#   inflating: data/video/frames/95-65.jpg
#   inflating: data/video/frames/95-66.jpg
#   inflating: data/video/frames/95-67.jpg
#   inflating: data/video/frames/95-68.jpg
#   inflating: data/video/frames/95-69.jpg
#   inflating: data/video/frames/9-57.jpg
#   inflating: data/video/frames/95-70.jpg
#   inflating: data/video/frames/95-71.jpg
#   inflating: data/video/frames/95-72.jpg
#   inflating: data/video/frames/95-73.jpg
#   inflating: data/video/frames/95-74.jpg
#   inflating: data/video/frames/95-75.jpg
#   inflating: data/video/frames/9-58.jpg
#   inflating: data/video/frames/9-59.jpg
#   inflating: data/video/frames/9-60.jpg
#   inflating: data/video/frames/96-01.jpg
#   inflating: data/video/frames/96-02.jpg
#   inflating: data/video/frames/96-03.jpg
#   inflating: data/video/frames/96-04.jpg
#   inflating: data/video/frames/96-05.jpg
#   inflating: data/video/frames/96-06.jpg
#   inflating: data/video/frames/96-07.jpg
#   inflating: data/video/frames/96-08.jpg
#   inflating: data/video/frames/96-09.jpg
#   inflating: data/video/frames/9-61.jpg
#   inflating: data/video/frames/96-10.jpg
#   inflating: data/video/frames/96-11.jpg
#   inflating: data/video/frames/96-12.jpg
#   inflating: data/video/frames/96-13.jpg
#   inflating: data/video/frames/96-14.jpg
#   inflating: data/video/frames/96-15.jpg
#   inflating: data/video/frames/96-16.jpg
#   inflating: data/video/frames/96-17.jpg
#   inflating: data/video/frames/96-18.jpg
#   inflating: data/video/frames/96-19.jpg
#   inflating: data/video/frames/9-62.jpg
#   inflating: data/video/frames/96-20.jpg
#   inflating: data/video/frames/96-21.jpg
#   inflating: data/video/frames/96-22.jpg
#   inflating: data/video/frames/96-23.jpg
#   inflating: data/video/frames/96-24.jpg
#   inflating: data/video/frames/96-25.jpg
#   inflating: data/video/frames/96-26.jpg
#   inflating: data/video/frames/96-27.jpg
#   inflating: data/video/frames/96-28.jpg
#   inflating: data/video/frames/96-29.jpg
#   inflating: data/video/frames/9-63.jpg
#   inflating: data/video/frames/96-30.jpg
#   inflating: data/video/frames/96-31.jpg
#   inflating: data/video/frames/96-32.jpg
#   inflating: data/video/frames/96-33.jpg
#   inflating: data/video/frames/96-34.jpg
#   inflating: data/video/frames/96-35.jpg
#   inflating: data/video/frames/96-36.jpg
#   inflating: data/video/frames/96-37.jpg
#   inflating: data/video/frames/96-38.jpg
#   inflating: data/video/frames/96-39.jpg
#   inflating: data/video/frames/9-64.jpg
#   inflating: data/video/frames/96-40.jpg
#   inflating: data/video/frames/96-41.jpg
#   inflating: data/video/frames/96-42.jpg
#   inflating: data/video/frames/96-43.jpg
#   inflating: data/video/frames/96-44.jpg
#   inflating: data/video/frames/96-45.jpg
#   inflating: data/video/frames/96-46.jpg
#   inflating: data/video/frames/96-47.jpg
#   inflating: data/video/frames/96-48.jpg
#   inflating: data/video/frames/96-49.jpg
#   inflating: data/video/frames/9-65.jpg
#   inflating: data/video/frames/96-50.jpg
#   inflating: data/video/frames/96-51.jpg
#   inflating: data/video/frames/96-52.jpg
#   inflating: data/video/frames/96-53.jpg
#   inflating: data/video/frames/96-54.jpg
#   inflating: data/video/frames/96-55.jpg
#   inflating: data/video/frames/96-56.jpg
#   inflating: data/video/frames/96-57.jpg
#   inflating: data/video/frames/96-58.jpg
#   inflating: data/video/frames/96-59.jpg
#   inflating: data/video/frames/9-66.jpg
#   inflating: data/video/frames/96-60.jpg
#   inflating: data/video/frames/96-61.jpg
#   inflating: data/video/frames/96-62.jpg
#   inflating: data/video/frames/96-63.jpg
#   inflating: data/video/frames/96-64.jpg
#   inflating: data/video/frames/96-65.jpg
#   inflating: data/video/frames/96-66.jpg
#   inflating: data/video/frames/96-67.jpg
#   inflating: data/video/frames/96-68.jpg
#   inflating: data/video/frames/96-69.jpg
#   inflating: data/video/frames/9-67.jpg
#   inflating: data/video/frames/96-70.jpg
#   inflating: data/video/frames/96-71.jpg
#   inflating: data/video/frames/96-72.jpg
#   inflating: data/video/frames/96-73.jpg
#   inflating: data/video/frames/96-74.jpg
#   inflating: data/video/frames/96-75.jpg
#   inflating: data/video/frames/9-68.jpg
#   inflating: data/video/frames/9-69.jpg
#   inflating: data/video/frames/9-70.jpg
#   inflating: data/video/frames/97-01.jpg
#   inflating: data/video/frames/97-02.jpg
#   inflating: data/video/frames/97-03.jpg
#   inflating: data/video/frames/97-04.jpg
#   inflating: data/video/frames/97-05.jpg
#   inflating: data/video/frames/97-06.jpg
#   inflating: data/video/frames/97-07.jpg
#   inflating: data/video/frames/97-08.jpg
#   inflating: data/video/frames/97-09.jpg
#   inflating: data/video/frames/9-71.jpg
#   inflating: data/video/frames/97-10.jpg
#   inflating: data/video/frames/97-11.jpg
#   inflating: data/video/frames/97-12.jpg
#   inflating: data/video/frames/97-13.jpg
#   inflating: data/video/frames/97-14.jpg
#   inflating: data/video/frames/97-15.jpg
#   inflating: data/video/frames/97-16.jpg
#   inflating: data/video/frames/97-17.jpg
#   inflating: data/video/frames/97-18.jpg
#   inflating: data/video/frames/97-19.jpg
#   inflating: data/video/frames/9-72.jpg
#   inflating: data/video/frames/97-20.jpg
#   inflating: data/video/frames/97-21.jpg
#   inflating: data/video/frames/97-22.jpg
#   inflating: data/video/frames/97-23.jpg
#   inflating: data/video/frames/97-24.jpg
#   inflating: data/video/frames/97-25.jpg
#   inflating: data/video/frames/97-26.jpg
#   inflating: data/video/frames/97-27.jpg
#   inflating: data/video/frames/97-28.jpg
#   inflating: data/video/frames/97-29.jpg
#   inflating: data/video/frames/9-73.jpg
#   inflating: data/video/frames/97-30.jpg
#   inflating: data/video/frames/97-31.jpg
#   inflating: data/video/frames/97-32.jpg
#   inflating: data/video/frames/97-33.jpg
#   inflating: data/video/frames/97-34.jpg
#   inflating: data/video/frames/97-35.jpg
#   inflating: data/video/frames/97-36.jpg
#   inflating: data/video/frames/97-37.jpg
#   inflating: data/video/frames/97-38.jpg
#   inflating: data/video/frames/97-39.jpg
#   inflating: data/video/frames/9-74.jpg
#   inflating: data/video/frames/97-40.jpg
#   inflating: data/video/frames/97-41.jpg
#   inflating: data/video/frames/97-42.jpg
#   inflating: data/video/frames/97-43.jpg
#   inflating: data/video/frames/97-44.jpg
#   inflating: data/video/frames/97-45.jpg
#   inflating: data/video/frames/97-46.jpg
#   inflating: data/video/frames/97-47.jpg
#   inflating: data/video/frames/97-48.jpg
#   inflating: data/video/frames/97-49.jpg
#   inflating: data/video/frames/9-75.jpg
#   inflating: data/video/frames/97-50.jpg
#   inflating: data/video/frames/97-51.jpg
#   inflating: data/video/frames/97-52.jpg
#   inflating: data/video/frames/97-53.jpg
#   inflating: data/video/frames/97-54.jpg
#   inflating: data/video/frames/97-55.jpg
#   inflating: data/video/frames/97-56.jpg
#   inflating: data/video/frames/97-57.jpg
#   inflating: data/video/frames/97-58.jpg
#   inflating: data/video/frames/97-59.jpg
#   inflating: data/video/frames/97-60.jpg
#   inflating: data/video/frames/97-61.jpg
#   inflating: data/video/frames/97-62.jpg
#   inflating: data/video/frames/97-63.jpg
#   inflating: data/video/frames/97-64.jpg
#   inflating: data/video/frames/97-65.jpg
#   inflating: data/video/frames/97-66.jpg
#   inflating: data/video/frames/97-67.jpg
#   inflating: data/video/frames/97-68.jpg
#   inflating: data/video/frames/97-69.jpg
#   inflating: data/video/frames/97-70.jpg
#   inflating: data/video/frames/97-71.jpg
#   inflating: data/video/frames/97-72.jpg
#   inflating: data/video/frames/97-73.jpg
#   inflating: data/video/frames/97-74.jpg
#   inflating: data/video/frames/97-75.jpg
#   inflating: data/video/frames/98-01.jpg
#   inflating: data/video/frames/98-02.jpg
#   inflating: data/video/frames/98-03.jpg
#   inflating: data/video/frames/98-04.jpg
#   inflating: data/video/frames/98-05.jpg
#   inflating: data/video/frames/98-06.jpg
#   inflating: data/video/frames/98-07.jpg
#   inflating: data/video/frames/98-08.jpg
#   inflating: data/video/frames/98-09.jpg
#   inflating: data/video/frames/98-10.jpg
#   inflating: data/video/frames/98-11.jpg
#   inflating: data/video/frames/98-12.jpg
#   inflating: data/video/frames/98-13.jpg
#   inflating: data/video/frames/98-14.jpg
#   inflating: data/video/frames/98-15.jpg
#   inflating: data/video/frames/98-16.jpg
#   inflating: data/video/frames/98-17.jpg
#   inflating: data/video/frames/98-18.jpg
#   inflating: data/video/frames/98-19.jpg
#   inflating: data/video/frames/98-20.jpg
#   inflating: data/video/frames/98-21.jpg
#   inflating: data/video/frames/98-22.jpg
#   inflating: data/video/frames/98-23.jpg
#   inflating: data/video/frames/98-24.jpg
#   inflating: data/video/frames/98-25.jpg
#   inflating: data/video/frames/98-26.jpg
#   inflating: data/video/frames/98-27.jpg
#   inflating: data/video/frames/98-28.jpg
#   inflating: data/video/frames/98-29.jpg
#   inflating: data/video/frames/98-30.jpg
#   inflating: data/video/frames/98-31.jpg
#   inflating: data/video/frames/98-32.jpg
#   inflating: data/video/frames/98-33.jpg
#   inflating: data/video/frames/98-34.jpg
#   inflating: data/video/frames/98-35.jpg
#   inflating: data/video/frames/98-36.jpg
#   inflating: data/video/frames/98-37.jpg
#   inflating: data/video/frames/98-38.jpg
#   inflating: data/video/frames/98-39.jpg
#   inflating: data/video/frames/98-40.jpg
#   inflating: data/video/frames/98-41.jpg
#   inflating: data/video/frames/98-42.jpg
#   inflating: data/video/frames/98-43.jpg
#   inflating: data/video/frames/98-44.jpg
#   inflating: data/video/frames/98-45.jpg
#   inflating: data/video/frames/98-46.jpg
#   inflating: data/video/frames/98-47.jpg
#   inflating: data/video/frames/98-48.jpg
#   inflating: data/video/frames/98-49.jpg
#   inflating: data/video/frames/98-50.jpg
#   inflating: data/video/frames/98-51.jpg
#   inflating: data/video/frames/98-52.jpg
#   inflating: data/video/frames/98-53.jpg
#   inflating: data/video/frames/98-54.jpg
#   inflating: data/video/frames/98-55.jpg
#   inflating: data/video/frames/98-56.jpg
#   inflating: data/video/frames/98-57.jpg
#   inflating: data/video/frames/98-58.jpg
#   inflating: data/video/frames/98-59.jpg
#   inflating: data/video/frames/98-60.jpg
#   inflating: data/video/frames/98-61.jpg
#   inflating: data/video/frames/98-62.jpg
#   inflating: data/video/frames/98-63.jpg
#   inflating: data/video/frames/98-64.jpg
#   inflating: data/video/frames/98-65.jpg
#   inflating: data/video/frames/98-66.jpg
#   inflating: data/video/frames/98-67.jpg
#   inflating: data/video/frames/98-68.jpg
#   inflating: data/video/frames/98-69.jpg
#   inflating: data/video/frames/98-70.jpg
#   inflating: data/video/frames/98-71.jpg
#   inflating: data/video/frames/98-72.jpg
#   inflating: data/video/frames/98-73.jpg
#   inflating: data/video/frames/98-74.jpg
#   inflating: data/video/frames/98-75.jpg
#   inflating: data/video/frames/99-01.jpg
#   inflating: data/video/frames/99-02.jpg
#   inflating: data/video/frames/99-03.jpg
#   inflating: data/video/frames/99-04.jpg
#   inflating: data/video/frames/99-05.jpg
#   inflating: data/video/frames/99-06.jpg
#   inflating: data/video/frames/99-07.jpg
#   inflating: data/video/frames/99-08.jpg
#   inflating: data/video/frames/99-09.jpg
#   inflating: data/video/frames/99-10.jpg
#   inflating: data/video/frames/99-11.jpg
#   inflating: data/video/frames/99-12.jpg
#   inflating: data/video/frames/99-13.jpg
#   inflating: data/video/frames/99-14.jpg
#   inflating: data/video/frames/99-15.jpg
#   inflating: data/video/frames/99-16.jpg
#   inflating: data/video/frames/99-17.jpg
#   inflating: data/video/frames/99-18.jpg
#   inflating: data/video/frames/99-19.jpg
#   inflating: data/video/frames/99-20.jpg
#   inflating: data/video/frames/99-21.jpg
#   inflating: data/video/frames/99-22.jpg
#   inflating: data/video/frames/99-23.jpg
#   inflating: data/video/frames/99-24.jpg
#   inflating: data/video/frames/99-25.jpg
#   inflating: data/video/frames/99-26.jpg
#   inflating: data/video/frames/99-27.jpg
#   inflating: data/video/frames/99-28.jpg
#   inflating: data/video/frames/99-29.jpg
#   inflating: data/video/frames/99-30.jpg
#   inflating: data/video/frames/99-31.jpg
#   inflating: data/video/frames/99-32.jpg
#   inflating: data/video/frames/99-33.jpg
#   inflating: data/video/frames/99-34.jpg
#   inflating: data/video/frames/99-35.jpg
#   inflating: data/video/frames/99-36.jpg
#   inflating: data/video/frames/99-37.jpg
#   inflating: data/video/frames/99-38.jpg
#   inflating: data/video/frames/99-39.jpg
#   inflating: data/video/frames/99-40.jpg
#   inflating: data/video/frames/99-41.jpg
#   inflating: data/video/frames/99-42.jpg
#   inflating: data/video/frames/99-43.jpg
#   inflating: data/video/frames/99-44.jpg
#   inflating: data/video/frames/99-45.jpg
#   inflating: data/video/frames/99-46.jpg
#   inflating: data/video/frames/99-47.jpg
#   inflating: data/video/frames/99-48.jpg
#   inflating: data/video/frames/99-49.jpg
#   inflating: data/video/frames/99-50.jpg
#   inflating: data/video/frames/99-51.jpg
#   inflating: data/video/frames/99-52.jpg
#   inflating: data/video/frames/99-53.jpg
#   inflating: data/video/frames/99-54.jpg
#   inflating: data/video/frames/99-55.jpg
#   inflating: data/video/frames/99-56.jpg
#   inflating: data/video/frames/99-57.jpg
#   inflating: data/video/frames/99-58.jpg
#   inflating: data/video/frames/99-59.jpg
#   inflating: data/video/frames/99-60.jpg
#   inflating: data/video/frames/99-61.jpg
#   inflating: data/video/frames/99-62.jpg
#   inflating: data/video/frames/99-63.jpg
#   inflating: data/video/frames/99-64.jpg
#   inflating: data/video/frames/99-65.jpg
#   inflating: data/video/frames/99-66.jpg
#   inflating: data/video/frames/99-67.jpg
#   inflating: data/video/frames/99-68.jpg
#   inflating: data/video/frames/99-69.jpg
#   inflating: data/video/frames/99-70.jpg
#   inflating: data/video/frames/99-71.jpg
#   inflating: data/video/frames/99-72.jpg
#   inflating: data/video/frames/99-73.jpg
#   inflating: data/video/frames/99-74.jpg
#   inflating: data/video/frames/99-75.jpg
#   inflating: data/video/MTCNN_detect.py
#   inflating: data/video/valid_frame.txt
#   inflating: data/video/video_download.py
#    creating: data/video/video_train/

# %%
# import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import librosa
from scipy.io import wavfile

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Dense, Conv2D, LSTM, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Activation, Flatten, TimeDistributed, Reshape
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import os
# import sys
import glob
from datetime import datetime

# %%
import sys
sys.path.append('../lib')
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import optimizers
import os
import tensorflow as tf

# %%
from tensorflow.keras import optimizers
# from tensorflow.keras.layers import Dense, Convolution3D, MaxPooling3D, ZeroPadding3D, Dropout, Flatten, BatchNormalization, ReLU
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Dense, Convolution2D, Bidirectional, UpSampling2D, UpSampling3D, concatenate
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization, ReLU, Reshape, Permute, Lambda, TimeDistributed
from tensorflow.keras.models import Model, load_model
# from keras.layers.recurrent import LSTM
from tensorflow.keras.layers import LSTM
from tensorflow.keras.initializers import he_normal, glorot_uniform
# from keras.layers import Deconvolution2D
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import TensorBoard

# %%
def audio_discriminate_loss2(gamma=0.1,beta = 2*0.1,num_speaker=2):
    def loss_func(S_true,S_pred,gamma=gamma,beta=beta,num_speaker=num_speaker):
        import keras.backend as K
        sum_mtr = K.zeros_like(S_true[:,:,:,:,0])
        for i in range(num_speaker):
            sum_mtr += K.square(S_true[:,:,:,:,i]-S_pred[:,:,:,:,i])
            for j in range(num_speaker):
                if i != j:
                    sum_mtr -= gamma*(K.square(S_true[:,:,:,:,i]-S_pred[:,:,:,:,j]))

        for i in range(num_speaker):
            for j in range(i+1,num_speaker):
                #sum_mtr -= beta*K.square(S_pred[:,:,:,i]-S_pred[:,:,:,j])
                #sum_mtr += beta*K.square(S_true[:,:,:,:,i]-S_true[:,:,:,:,j])
                pass
        #sum = K.sum(K.maximum(K.flatten(sum_mtr),0))

        loss = K.mean(K.flatten(sum_mtr))

        return loss
    return loss_func

audio_loss = audio_discriminate_loss2

# %%
import tensorflow.keras as keras

class AVGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, filename, database_dir_path, X1dim=(298, 257, 2), X2dim=(75, 1, 1792, 2), ydim=(298, 257, 2, 2), batch_size=4, shuffle=True):
        'Initialization'
        self.filename = filename
        self.X1dim = X1dim
        self.X2dim = X2dim
        self.ydim = ydim
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.database_dir_path = database_dir_path

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.filename) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list
        filename_temp = [self.filename[k] for k in indexes]

        # Generate data
        [X1, X2], y = self.__data_generation(filename_temp)

        return [X1, X2], y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.filename))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, filename_temp):
        'Generates data containing batch_size samples'
        # Initialization
        X1 = np.empty((self.batch_size, *self.X1dim))
        X2 = np.empty((self.batch_size, *self.X2dim))
        y = np.empty((self.batch_size, *self.ydim))

        # Generate data
        for i, ID in enumerate(filename_temp):
            info = ID.strip().split(' ')
            X1[i, ] = np.load(self.database_dir_path+'audio/AV_model_database/mix/' + info[0])
            for j in range(2):
                y[i, :, :, :, j] = np.load(self.database_dir_path+'audio/AV_model_database/crm/' + info[j + 1])
                X2[i, :, :, :, j] = np.load(self.database_dir_path+'video/face_emb/' + info[j + 3])

        return [X1, X2], y

# %%
def AV_model(people_num=2):
    def UpSampling2DBilinear(size):
        return Lambda(lambda x: tf.image.resize_bilinear(x, size, align_corners=True))

    def sliced(x, index):
        return x[:, :, :, index]

    # --------------------------- AS start ---------------------------
    audio_input = Input(shape=(298, 257, 2))
    print('as_0:', audio_input.shape)
    as_conv1 = Convolution2D(96, kernel_size=(1, 7), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='as_conv1')(audio_input)
    as_conv1 = BatchNormalization()(as_conv1)
    as_conv1 = ReLU()(as_conv1)
    print('as_1:', as_conv1.shape)

    as_conv2 = Convolution2D(96, kernel_size=(7, 1), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='as_conv2')(as_conv1)
    as_conv2 = BatchNormalization()(as_conv2)
    as_conv2 = ReLU()(as_conv2)
    print('as_2:', as_conv2.shape)

    as_conv3 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='as_conv3')(as_conv2)
    as_conv3 = BatchNormalization()(as_conv3)
    as_conv3 = ReLU()(as_conv3)
    print('as_3:', as_conv3.shape)

    as_conv4 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(2, 1), name='as_conv4')(as_conv3)
    as_conv4 = BatchNormalization()(as_conv4)
    as_conv4 = ReLU()(as_conv4)
    print('as_4:', as_conv4.shape)

    as_conv5 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(4, 1), name='as_conv5')(as_conv4)
    as_conv5 = BatchNormalization()(as_conv5)
    as_conv5 = ReLU()(as_conv5)
    print('as_5:', as_conv5.shape)

    as_conv6 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(8, 1), name='as_conv6')(as_conv5)
    as_conv6 = BatchNormalization()(as_conv6)
    as_conv6 = ReLU()(as_conv6)
    print('as_6:', as_conv6.shape)

    as_conv7 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(16, 1), name='as_conv7')(as_conv6)
    as_conv7 = BatchNormalization()(as_conv7)
    as_conv7 = ReLU()(as_conv7)
    print('as_7:', as_conv7.shape)

    as_conv8 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(32, 1), name='as_conv8')(as_conv7)
    as_conv8 = BatchNormalization()(as_conv8)
    as_conv8 = ReLU()(as_conv8)
    print('as_8:', as_conv8.shape)

    as_conv9 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='as_conv9')(as_conv8)
    as_conv9 = BatchNormalization()(as_conv9)
    as_conv9 = ReLU()(as_conv9)
    print('as_9:', as_conv9.shape)

    as_conv10 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(2, 2), name='as_conv10')(as_conv9)
    as_conv10 = BatchNormalization()(as_conv10)
    as_conv10 = ReLU()(as_conv10)
    print('as_10:', as_conv10.shape)

    as_conv11 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(4, 4), name='as_conv11')(as_conv10)
    as_conv11 = BatchNormalization()(as_conv11)
    as_conv11 = ReLU()(as_conv11)
    print('as_11:', as_conv11.shape)

    as_conv12 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(8, 8), name='as_conv12')(as_conv11)
    as_conv12 = BatchNormalization()(as_conv12)
    as_conv12 = ReLU()(as_conv12)
    print('as_12:', as_conv12.shape)

    as_conv13 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(16, 16), name='as_conv13')(as_conv12)
    as_conv13 = BatchNormalization()(as_conv13)
    as_conv13 = ReLU()(as_conv13)
    print('as_13:', as_conv13.shape)

    as_conv14 = Convolution2D(96, kernel_size=(5, 5), strides=(1, 1), padding='same', dilation_rate=(32, 32), name='as_conv14')(as_conv13)
    as_conv14 = BatchNormalization()(as_conv14)
    as_conv14 = ReLU()(as_conv14)
    print('as_14:', as_conv14.shape)

    as_conv15 = Convolution2D(8, kernel_size=(1, 1), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='as_conv15')(as_conv14)
    as_conv15 = BatchNormalization()(as_conv15)
    as_conv15 = ReLU()(as_conv15)
    print('as_15:', as_conv15.shape)

    AS_out = Reshape((298, 8 * 257))(as_conv15)
    print('AS_out:', AS_out.shape)
    # --------------------------- AS end ---------------------------

    # --------------------------- VS_model start ---------------------------
    VS_model = Sequential()
    VS_model.add(Convolution2D(256, kernel_size=(7, 1), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='vs_conv1'))
    VS_model.add(BatchNormalization())
    VS_model.add(ReLU())
    VS_model.add(Convolution2D(256, kernel_size=(5, 1), strides=(1, 1), padding='same', dilation_rate=(1, 1), name='vs_conv2'))
    VS_model.add(BatchNormalization())
    VS_model.add(ReLU())
    VS_model.add(Convolution2D(256, kernel_size=(5, 1), strides=(1, 1), padding='same', dilation_rate=(2, 1), name='vs_conv3'))
    VS_model.add(BatchNormalization())
    VS_model.add(ReLU())
    VS_model.add(Convolution2D(256, kernel_size=(5, 1), strides=(1, 1), padding='same', dilation_rate=(4, 1), name='vs_conv4'))
    VS_model.add(BatchNormalization())
    VS_model.add(ReLU())
    VS_model.add(Convolution2D(256, kernel_size=(5, 1), strides=(1, 1), padding='same', dilation_rate=(8, 1), name='vs_conv5'))
    VS_model.add(BatchNormalization())
    VS_model.add(ReLU())
    VS_model.add(Convolution2D(256, kernel_size=(5, 1), strides=(1, 1), padding='same', dilation_rate=(16, 1), name='vs_conv6'))
    VS_model.add(BatchNormalization())
    VS_model.add(ReLU())
    VS_model.add(Reshape((75, 256, 1)))
    VS_model.add(UpSampling2DBilinear((298, 256)))
    VS_model.add(Reshape((298, 256)))
    # --------------------------- VS_model end ---------------------------

    video_input = Input(shape=(75, 1, 1792, people_num))
    AVfusion_list = [AS_out]
    for i in range(people_num):
        single_input = Lambda(sliced, arguments={'index': i})(video_input)
        VS_out = VS_model(single_input)
        AVfusion_list.append(VS_out)

    AVfusion = concatenate(AVfusion_list, axis=2)
    AVfusion = TimeDistributed(Flatten())(AVfusion)
    print('AVfusion:', AVfusion.shape)

    lstm = Bidirectional(LSTM(400, input_shape=(298, 8 * 257), return_sequences=True), merge_mode='sum')(AVfusion)
    print('lstm:', lstm.shape)

    fc1 = Dense(600, name="fc1", activation='relu', kernel_initializer=he_normal(seed=27))(lstm)
    print('fc1:', fc1.shape)
    fc2 = Dense(600, name="fc2", activation='relu', kernel_initializer=he_normal(seed=42))(fc1)
    print('fc2:', fc2.shape)
    fc3 = Dense(600, name="fc3", activation='relu', kernel_initializer=he_normal(seed=65))(fc2)
    print('fc3:', fc3.shape)

    complex_mask = Dense(257 * 2 * people_num, name="complex_mask", kernel_initializer=glorot_uniform(seed=87))(fc3)
    print('complex_mask:', complex_mask.shape)

    complex_mask_out = Reshape((298, 257, 2, people_num))(complex_mask)
    print('complex_mask_out:', complex_mask_out.shape)

    AV_model = Model(inputs=[audio_input, video_input], outputs=complex_mask_out)

    # # compile AV_model
    # AV_model.compile(optimizer='adam', loss='mse')

    return AV_model

# %%
import os, argparse
from tensorflow.python.tools.freeze_graph import freeze_graph
from keras import Model
from keras.utils import multi_gpu_model

class ModelMGPU(Model):
    def __init__(self, ser_model, gpus):
        pmodel = multi_gpu_model(ser_model, gpus)
        self.__dict__.update(pmodel.__dict__)
        self._smodel = ser_model

    def __getattribute__(self, attrname):
        '''Override load and save methods to be used from the serial-model. The
        serial-model holds references to the weights in the multi-gpu model.
        '''
        # return Model.__getattribute__(self, attrname)
        if 'load' in attrname or 'save' in attrname:
            return getattr(self._smodel, attrname)

        return super(ModelMGPU, self).__getattribute__(attrname)

def latest_file(dir):
    # get latest checkpoint
    lists = os.listdir(dir)
    lists.sort(key=lambda fn: os.path.getmtime(dir + fn))
    file_latest = os.path.join(dir, lists[-1])
    return file_latest

# %%
# create AV model
#############################################################
RESTORE = False
# If set true, continue training from last checkpoint
# needed change 1:h5 file name, 2:epochs num, 3:initial_epoch

# super parameters
people_num = 2
epochs = 100
initial_epoch = 20
batch_size = 2 # 4 to feed one 16G GPU
gamma_loss = 0.1
beta_loss = gamma_loss*2

# physical devices option to accelerate training process
workers = 1 # num of core
use_multiprocessing = False
NUM_GPU = 1

# PATH
path = 'saved_AV_models' # model path
database_dir_path = 'data/'
#############################################################

# %%
# create folder to save models
folder = os.path.exists(path)
if not folder:
	os.makedirs(path)
	print('create folder to save models')
filepath = path + "/AVmodel-" + str(people_num) + "p-{epoch:03d}-{val_loss:.5f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')


#############################################################

# %%
# automatically change lr
def scheduler(epoch):
	ini_lr = 0.00001
	lr = ini_lr
	if epoch >= 5:
		lr = ini_lr / 5
	if epoch >= 10:
		lr = ini_lr / 10
	return lr

rlr = LearningRateScheduler(scheduler, verbose=1)

# %%
# read train and val file name
# format: mix.npy single.npy single.npy
trainfile = []
valfile = []
with open((database_dir_path+'AV_log/AVdataset_train.txt'), 'r') as t:
	trainfile = t.readlines()
with open((database_dir_path+'AV_log/AVdataset_val.txt'), 'r') as v:
	valfile = v.readlines()
# ///////////////////////////////////////////////////////// #

# the training steps
if RESTORE:
	latest_file = latest_file(path+'/')
	print("Restoring model from:", latest_file)
	AV_model = load_model(latest_file,custom_objects={"tf": tf})
	info = latest_file.strip().split('-')
	initial_epoch = int(info[-2])
else:
	AV_model = AV_model(people_num)

train_generator = AVGenerator(trainfile,database_dir_path= database_dir_path, batch_size=batch_size, shuffle=True)
val_generator = AVGenerator(valfile,database_dir_path=database_dir_path, batch_size=batch_size, shuffle=True)
# Out:
# as_0: (?, 298, 257, 2)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# as_1: (?, 298, 257, 96)
# as_2: (?, 298, 257, 96)
# as_3: (?, 298, 257, 96)
# as_4: (?, 298, 257, 96)
# as_5: (?, 298, 257, 96)
# as_6: (?, 298, 257, 96)
# as_7: (?, 298, 257, 96)
# as_8: (?, 298, 257, 96)
# as_9: (?, 298, 257, 96)
# as_10: (?, 298, 257, 96)
# as_11: (?, 298, 257, 96)
# as_12: (?, 298, 257, 96)
# as_13: (?, 298, 257, 96)
# as_14: (?, 298, 257, 96)
# as_15: (?, 298, 257, 8)
# AS_out: (?, 298, 2056)
# AVfusion: (?, 298, 2568)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# lstm: (?, 298, 400)
# fc1: (?, 298, 600)
# fc2: (?, 298, 600)
# fc3: (?, 298, 600)
# complex_mask: (?, 298, 1028)
# complex_mask_out: (?, 298, 257, 2, 2)

# %%
adam = optimizers.Adam()
loss = audio_loss(gamma=gamma_loss,beta=beta_loss, num_speaker=people_num)
AV_model.compile(optimizer=adam, loss=loss, metrics=['accuracy'])
AV_model.summary()
AV_model.fit_generator(generator=train_generator,
             validation_data=val_generator,
             epochs=epochs,
             workers = workers,
             use_multiprocessing= use_multiprocessing,
             callbacks=[TensorBoard(log_dir='./log_AV'), checkpoint, rlr],
             initial_epoch=initial_epoch
             )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 298, 257, 2) 0
# __________________________________________________________________________________________________
# as_conv1 (Conv2D)               (None, 298, 257, 96) 1440        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 298, 257, 96) 384         as_conv1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 298, 257, 96) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# as_conv2 (Conv2D)               (None, 298, 257, 96) 64608       re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 298, 257, 96) 384         as_conv2[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# as_conv3 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 298, 257, 96) 384         as_conv3[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# as_conv4 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 298, 257, 96) 384         as_conv4[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# as_conv5 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 298, 257, 96) 384         as_conv5[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# as_conv6 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 298, 257, 96) 384         as_conv6[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# as_conv7 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 298, 257, 96) 384         as_conv7[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# as_conv8 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 298, 257, 96) 384         as_conv8[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# as_conv9 (Conv2D)               (None, 298, 257, 96) 230496      re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 298, 257, 96) 384         as_conv9[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# as_conv10 (Conv2D)              (None, 298, 257, 96) 230496      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 298, 257, 96) 384         as_conv10[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 298, 257, 96) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# as_conv11 (Conv2D)              (None, 298, 257, 96) 230496      re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 298, 257, 96) 384         as_conv11[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 298, 257, 96) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# as_conv12 (Conv2D)              (None, 298, 257, 96) 230496      re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 298, 257, 96) 384         as_conv12[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 298, 257, 96) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# as_conv13 (Conv2D)              (None, 298, 257, 96) 230496      re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 298, 257, 96) 384         as_conv13[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 298, 257, 96) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# as_conv14 (Conv2D)              (None, 298, 257, 96) 230496      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 298, 257, 96) 384         as_conv14[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 298, 257, 96) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# as_conv15 (Conv2D)              (None, 298, 257, 8)  776         re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 298, 257, 8)  32          as_conv15[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 75, 1, 1792, 0
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 298, 257, 8)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 75, 1, 2)     0           input_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 75, 1, 2)     0           input_3[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 298, 2056)    0           re_lu_14[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 298, 256)     1649664     lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 298, 2568)    0           reshape[0][0]
#                                                                  sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 298, 2568)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 298, 400)     9500800     time_distributed[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 298, 600)     240600      bidirectional[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 298, 600)     360600      fc1[0][0]
# __________________________________________________________________________________________________
# fc3 (Dense)                     (None, 298, 600)     360600      fc2[0][0]
# __________________________________________________________________________________________________
# complex_mask (Dense)            (None, 298, 1028)    617828      fc3[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 298, 257, 2,  0           complex_mask[0][0]
# ==================================================================================================
# Total params: 15,568,276
# Trainable params: 15,562,500
# Non-trainable params: 5,776
# __________________________________________________________________________________________________
# None
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.0000000000000002e-06.
# Epoch 21/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#  65/198 [========>.....................] - ETA: 16:38 - loss: 0.9971 - acc: 0.4988

# %%
# Check connection to GPU
tf.test.gpu_device_name()

# %%
if 'COLAB_TPU_ADDR' not in os.environ: 
  print('Not connected to TPU') 
else: 
  print("Connected to TPU")
